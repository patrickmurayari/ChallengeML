# %% [markdown]
# # 1. Cargar librerías necesarias

# %%
import pandas as pd

# %% [markdown]
# # 2.Defino la ruta base para facilitar la carga

# %%
DATA_PATH = '../data/raw/'

# %% [markdown]
# # 3. Cargar el dataset de Recorridos

# %%
df_recorridos =  pd.read_csv(DATA_PATH + 'badata_ecobici_recorridos_realizados_2024.csv')
df_usuarios = pd.read_csv(DATA_PATH + 'usuarios_ecobici_2024.csv')

# %% [markdown]
# # ---- Expploracion de df_recorridos ---

# %%
print("--- Recorridos: Informacion General ---")
#Mustra la cantidad de filas y coumnas
print(f"Filas:{df_recorridos.shape[0]}, Columas: {df_recorridos.shape[1]}\n")
# Out:
# --- Recorridos: Informacion General ---
# Filas:3559284, Columas: 17

# %%
#Muestra los tipos de datos
print("Tipos de datos:")
print(df_recorridos.dtypes)
print("-" * 30)
# Out:
# Tipos de datos:
# id_recorrido                    int64
# duracion_recorrido              int64
# fecha_origen_recorrido         object
# id_estacion_origen              int64
# nombre_estacion_origen         object
# direccion_estacion_origen      object
# long_estacion_origen          float64
# lat_estacion_origen           float64
# fecha_destino_recorrido        object
# id_estacion_destino             int64
# nombre_estacion_destino        object
# direccion_estacion_destino     object
# long_estacion_destino         float64
# lat_estacion_destino          float64
# id_usuario                    float64
# modelo_bicicleta               object
# genero                         object
# dtype: object
# ------------------------------

# %%
#Muestra valores nulos por columna
print("Valores nulos por columna")
print(df_recorridos.isnull().sum())
# Out:
# Valores nulos por columna
# id_recorrido                      0
# duracion_recorrido                0
# fecha_origen_recorrido            0
# id_estacion_origen                0
# nombre_estacion_origen            0
# direccion_estacion_origen         0
# long_estacion_origen              0
# lat_estacion_origen               0
# fecha_destino_recorrido        3379
# id_estacion_destino               0
# nombre_estacion_destino           0
# direccion_estacion_destino        0
# long_estacion_destino             0
# lat_estacion_destino              0
# id_usuario                        0
# modelo_bicicleta                  0
# genero                        11946
# dtype: int64

# %%
#Exploracion de df_usuarios
print("--- Recorridos: Informacion General ---")
#Mustra la cantidad de filas y coumnas
print(f"Filas:{df_usuarios.shape[0]}, Columas: {df_usuarios.shape[1]}\n")
# Out:
# --- Recorridos: Informacion General ---
# Filas:197077, Columas: 5

# %%
#Muestra los tipos de datos
print("Tipos de datos:")
print(df_usuarios.dtypes)
print("-" * 30)
# Out:
# Tipos de datos:
# id_usuario         int64
# genero_usuario    object
# edad_usuario       int64
# fecha_alta        object
# hora_alta         object
# dtype: object
# ------------------------------

# %%
print("Valores nulos por columna")
print(df_usuarios.isnull().sum())
# Out:
# Valores nulos por columna
# id_usuario        0
# genero_usuario    0
# edad_usuario      0
# fecha_alta        0
# hora_alta         0
# dtype: int64
